# %% [markdown]
# # UNEMPLOYMENT IN INDIA

# %%
# REQUIRED LIBERIES

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt
import calendar
import plotly.graph_objects as go

import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline

# %%
#IMPORTING THE DATA
df=pd.read_csv('Unemployment in India.csv')

# %%
df
# Out:
#              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1    Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2    Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3    Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4    Andhra Pradesh   30-09-2019    Monthly                              5.17
# ..              ...          ...        ...                               ...
# 736     West Bengal   29-02-2020    Monthly                              7.55
# 737     West Bengal   31-03-2020    Monthly                              6.67
# 738     West Bengal   30-04-2020    Monthly                             15.63
# 739     West Bengal   31-05-2020    Monthly                             15.22
# 740     West Bengal   30-06-2020    Monthly                              9.86
#
# ...

# %%
df.head()
# Out:
#            Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1  Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2  Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3  Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4  Andhra Pradesh   30-09-2019    Monthly                              5.17
#
#     Estimated Employed   Estimated Labour Participation Rate (%)   Area
# 0             11999139                                     43.24  Rural
# 1             11755881                                     42.05  Rural
# 2             12086707                                     43.50  Rural
# 3             12285693                                     43.97  Rural
# 4             12256762                                     44.68  Rural

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 741 entries, 0 to 740
# Data columns (total 7 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Region                                    741 non-null    object
#  1    Date                                     741 non-null    object
#  2    Frequency                                741 non-null    object
#  3    Estimated Unemployment Rate (%)          741 non-null    float64
#  4    Estimated Employed                       741 non-null    int64
#  5    Estimated Labour Participation Rate (%)  741 non-null    float64
#  6   Area                                      741 non-null    object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 40.7+ KB

# %%
df.isnull().sum()
# Out:
# Region                                      0
#  Date                                       0
#  Frequency                                  0
#  Estimated Unemployment Rate (%)            0
#  Estimated Employed                         0
#  Estimated Labour Participation Rate (%)    0
# Area                                        0
# dtype: int64

# %%
df.shape
# Out:
# (741, 7)

# %%
df.columns
# Out:
# Index(['Region', ' Date', ' Frequency', ' Estimated Unemployment Rate (%)',
#        ' Estimated Employed', ' Estimated Labour Participation Rate (%)',
#        'Area'],
#       dtype='object')

# %%
df.columns = ['Region', 'Date', 'Frequency', 'Estimates Unemployment Rate (%)', 
              'Estimates Employed', 'Estimated Labour Participation Rate(%)','Area']

# %%
df['Date'] = pd.to_datetime(df['Date'],dayfirst= True)

# %%
df['Frequency'] = df['Frequency'].astype('category')
df['Region'] = df['Region'].astype('category')

# %%
df.Region.value_counts()
# Out:
# Region
# West Bengal         29
# Karnataka           28
# Uttar Pradesh       28
# Tripura             28
# Telangana           28
# Tamil Nadu          28
# Rajasthan           28
# Punjab              28
# Odisha              28
# Maharashtra         28
# Kerala              28
# Andhra Pradesh      28
# Jharkhand           28
# Himachal Pradesh    28
# Haryana             28
# Gujarat             28
# Delhi               28
# Chhattisgarh        28
# Bihar               28
# Madhya Pradesh      28
# Meghalaya           27
# Uttarakhand         27
# Assam               26
# Puducherry          26
# Goa                 24
# Jammu & Kashmir     21
# Sikkim              17
# Chandigarh          12
# Name: count, dtype: int64

# %%
df['Date'] = pd.to_datetime(df['Date'],dayfirst = True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 741 entries, 0 to 740
# Data columns (total 7 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Region                                  741 non-null    category
#  1   Date                                    741 non-null    datetime64[ns]
#  2   Frequency                               741 non-null    category
#  3   Estimates Unemployment Rate (%)         741 non-null    float64
#  4   Estimates Employed                      741 non-null    int64
#  5   Estimated Labour Participation Rate(%)  741 non-null    float64
#  6   Area                                    741 non-null    object
# dtypes: category(2), datetime64[ns](1), float64(2), int64(1), object(1)
# memory usage: 31.9+ KB

# %%
df
# Out:
#              Region       Date Frequency  Estimates Unemployment Rate (%)  \
# 0    Andhra Pradesh 2019-05-31   Monthly                             3.65
# 1    Andhra Pradesh 2019-06-30   Monthly                             3.05
# 2    Andhra Pradesh 2019-07-31   Monthly                             3.75
# 3    Andhra Pradesh 2019-08-31   Monthly                             3.32
# 4    Andhra Pradesh 2019-09-30   Monthly                             5.17
# ..              ...        ...       ...                              ...
# 736     West Bengal 2020-02-29   Monthly                             7.55
# 737     West Bengal 2020-03-31   Monthly                             6.67
# 738     West Bengal 2020-04-30   Monthly                            15.63
# 739     West Bengal 2020-05-31   Monthly                            15.22
# 740     West Bengal 2020-06-30   Monthly                             9.86
#
#      Estimates Employed  Estimated Labour Participation Rate(%)   Area
# ...

# %%
df['Date'] = pd.to_datetime(df['Date'], dayfirst=True)

df['Frequency'] = df['Frequency'].astype('category')
df['Region'] = df['Region'].astype('category')

# %%
# Extracting month from 'Date' and creating a 'Month' column
df['Month'] = df['Date'].dt.month

# Converting 'Month' to integer format
df['Month_int'] = df['Month'].apply(lambda x: int(x))

# Mapping integer month values to abbreviated month names
df['Month_name'] = df['Month_int'].apply(lambda x: calendar.month_abbr[x])

# %%
# Dropping the original 'Month' column
df.drop(columns='Month', inplace=True)

# %%
df.head()
# Out:
#            Region       Date Frequency  Estimates Unemployment Rate (%)  \
# 0  Andhra Pradesh 2019-05-31   Monthly                             3.65
# 1  Andhra Pradesh 2019-06-30   Monthly                             3.05
# 2  Andhra Pradesh 2019-07-31   Monthly                             3.75
# 3  Andhra Pradesh 2019-08-31   Monthly                             3.32
# 4  Andhra Pradesh 2019-09-30   Monthly                             5.17
#
#    Estimates Employed  Estimated Labour Participation Rate(%)   Area  \
# 0            11999139                                   43.24  Rural
# 1            11755881                                   42.05  Rural
# 2            12086707                                   43.50  Rural
# 3            12285693                                   43.97  Rural
# 4            12256762                                   44.68  Rural
#
#    Month_int Month_name
# 0          5        May
# 1          6        Jun
# 2          7        Jul
# ...

# %%
df.describe()
# Out:
#                                 Date  Estimates Unemployment Rate (%)  \
# count                            741                       741.000000
# mean   2019-12-13 12:55:23.076923136                        11.778718
# min              2019-05-31 00:00:00                         0.000000
# 25%              2019-08-31 00:00:00                         4.660000
# 50%              2019-11-30 00:00:00                         8.330000
# 75%              2020-03-31 00:00:00                        15.880000
# max              2021-06-30 00:00:00                        76.740000
# std                              NaN                        10.716996
#
#        Estimates Employed  Estimated Labour Participation Rate(%)   Month_int
# count        7.410000e+02                              741.000000  741.000000
# mean         7.223382e+06                               42.627179    6.390013
# min          4.942000e+04                               13.330000    1.000000
# ...

# %%
df_stats = df[['Estimates Unemployment Rate (%)', 'Estimates Employed', 'Estimated Labour Participation Rate(%)']]
round(df_stats.describe().T, 2)
# Out:
#                                         count        mean         std  \
# Estimates Unemployment Rate (%)         741.0       11.78       10.72
# Estimates Employed                      741.0  7223382.33  8098918.15
# Estimated Labour Participation Rate(%)  741.0       42.63        8.11
#
#                                              min         25%         50%  \
# Estimates Unemployment Rate (%)             0.00        4.66        8.33
# Estimates Employed                      49420.00  1192616.00  4745178.00
# Estimated Labour Participation Rate(%)     13.33       38.07       41.14
#
#                                                 75%          max
# Estimates Unemployment Rate (%)               15.88        76.74
# Estimates Employed                      11304474.00  45777509.00
# Estimated Labour Participation Rate(%)        45.49        72.57

# %%
region_stats = df.groupby(['Region'])[['Estimates Unemployment Rate (%)', 'Estimates Employed', 'Estimated Labour Participation Rate(%)']].mean().reset_index()
round(region_stats, 2)
# Out:
#               Region  Estimates Unemployment Rate (%)  Estimates Employed  \
# 0     Andhra Pradesh                             7.48          8154093.18
# 1              Assam                             6.43          5354772.15
# 2              Bihar                            18.92         12366189.14
# 3         Chandigarh                            15.99           316831.25
# 4       Chhattisgarh                             9.24          4303498.57
# 5              Delhi                            16.50          2627512.86
# 6                Goa                             9.27           226308.33
# 7            Gujarat                             6.66         11402012.79
# 8            Haryana                            26.28          3557072.46
# 9   Himachal Pradesh                            18.54          1059823.71
# 10   Jammu & Kashmir                            16.19          1799931.67
# 11         Jharkhand                            20.58          4469240.43
# ...

# %%
heat_maps = df[[ 'Estimates Unemployment Rate (%)', 'Estimates Employed', 'Estimated Labour Participation Rate(%)']]
heat_maps = heat_maps.corr()
plt.figure(figsize=(9, 5))
sns.set_context('notebook', font_scale=1)
sns.heatmap(heat_maps, annot=True, cmap='summer')
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10, 8))
plt.title("Indian Unemployment")
sns.histplot(x="Estimates Unemployment Rate (%)", hue="Region", data=df)
plt.show()

# %%
import plotly.express as px
from plotly.offline import init_notebook_mode, iplot
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# Box plot of Unemployment Rate by State

fig = px.box(df, x='Region', y='Estimates Unemployment Rate (%)', color='Region', title='Unemployment Rate Per States', template='plotly')
fig.update_layout(xaxis={'categoryorder': 'total descending'})
fig.show()
# Out:
# <div>                            <div id="3a71b8ce-805c-4ab0-8aa5-3c616cd62397" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3a71b8ce-805c-4ab0-8aa5-3c616cd62397")) {                    Plotly.newPlot(                        "3a71b8ce-805c-4ab0-8aa5-3c616cd62397",                        [{"alignmentgroup":"True","hovertemplate":"Region=%{x}<br>Estimates Unemployment Rate (%)=%{y}<extra></extra>","legendgroup":"Andhra Pradesh","marker":{"color":"#636efa"},"name":"Andhra Pradesh","notched":false,"offsetgroup":"Andhra Pradesh","orientation":"v","showlegend":true,"x":["Andhra Pradesh","Andhra Pradesh","Andhra Pradesh","Andhra Pradesh","Andhra Pradesh","Andhra Pradesh","Andhra Pradesh","Andhra Pradesh","Andhra Pradesh","Andhra Pradesh","Andhra Pradesh
# ...

# %%
# # Scatter matrix
# import plotly.express as px
# print(type(df))
# fig = px.scatter_matrix(df, template='plotly',
#                         dimensions=['Estimates Unemployment Rate (%)', 'Estimates Employed', 'Estimated Labour Participation Rate(%)'],
#                         color='Region')

# fig.show()

# %%
# Bar plot of average Unemployment Rate by State

plot_ump = df[['Estimates Unemployment Rate (%)', 'Region']]
df_unemp = plot_ump.groupby('Region').mean().reset_index()
df_unemp = df_unemp.sort_values('Estimates Unemployment Rate (%)')
fig = px.bar(df_unemp, x='Region', y='Estimates Unemployment Rate (%)', color='Region',
             title='Average Unemployment Rate in each Region', template='plotly')
fig.show()
# Out:
# <div>                            <div id="6d4c33d0-aeca-421e-8ef3-2917aced70f1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6d4c33d0-aeca-421e-8ef3-2917aced70f1")) {                    Plotly.newPlot(                        "6d4c33d0-aeca-421e-8ef3-2917aced70f1",                        [{"alignmentgroup":"True","hovertemplate":"Region=%{x}<br>Estimates Unemployment Rate (%)=%{y}<extra></extra>","legendgroup":"Meghalaya","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Meghalaya","offsetgroup":"Meghalaya","orientation":"v","showlegend":true,"textposition":"auto","x":["Meghalaya"],"xaxis":"x","y":[4.7988888888888885],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}<br>Estimates Unemployment Rate (%)=%{y}<e
# ...

# %%
# Animated bar plot of Unemployment rate across region from Jan.2020 to Oct.2020

fig = px.bar(df, x='Region', y='Estimates Unemployment Rate (%)', animation_frame='Month_name', color='Region',
             title='Unemployment rate across region from Jan.2020 to Oct.2020', height=700, template='plotly')
fig.update_layout(xaxis={'categoryorder': 'total descending'})
fig.layout.updatemenus[0].buttons[0].args[1]["frame"]["duration"] = 2000
fig.show()
# Out:
# <div>                            <div id="24774b5e-4568-4c01-a6e9-d4e5e397650b" class="plotly-graph-div" style="height:700px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("24774b5e-4568-4c01-a6e9-d4e5e397650b")) {                    Plotly.newPlot(                        "24774b5e-4568-4c01-a6e9-d4e5e397650b",                        [{"alignmentgroup":"True","hovertemplate":"Region=%{x}<br>Month_name=May<br>Estimates Unemployment Rate (%)=%{y}<extra></extra>","legendgroup":"Andhra Pradesh","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Andhra Pradesh","offsetgroup":"Andhra Pradesh","orientation":"v","showlegend":true,"textposition":"auto","x":["Andhra Pradesh","Andhra Pradesh","Andhra Pradesh","Andhra Pradesh"],"xaxis":"x","y":[3.65,14.46,6.09,24.91],"yaxis":"y","type":"bar"},{"a
# ...

# %%
# Sunburst chart showing unemployment rate in each region and state

unemplo_df = df[[ 'Region', 'Estimates Unemployment Rate (%)', 'Estimates Employed', 'Estimated Labour Participation Rate(%)']]
unemplo = unemplo_df.groupby(['Region'])['Estimates Unemployment Rate (%)'].mean().reset_index()
fig = px.sunburst(unemplo, path=['Region'], values='Estimates Unemployment Rate (%)',
                  color_continuous_scale='Plasma', title='Estimates Unemployment rate in each region',
                  height=650)
fig.show()
# Out:
# <div>                            <div id="b9332fb1-4781-49c0-bf97-2a7fa4ad92d8" class="plotly-graph-div" style="height:650px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b9332fb1-4781-49c0-bf97-2a7fa4ad92d8")) {                    Plotly.newPlot(                        "b9332fb1-4781-49c0-bf97-2a7fa4ad92d8",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>Estimates Unemployment Rate (%)=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>","ids":["Andhra Pradesh","Assam","Bihar","Chandigarh","Chhattisgarh","Delhi","Goa","Gujarat","Haryana","Himachal Pradesh","Jammu & Kashmir","Jharkhand","Karnataka","Kerala","Madhya Pradesh","Maharashtra","Meghalaya","Odisha","Puducherry","Punjab","Rajasthan","Sikkim","Tamil Nadu"
# ...

# %%
fig = px.scatter_geo(df,'Area', color="Region",
                     hover_name="Region", size="Estimates Unemployment Rate (%)",
                     animation_frame="Month_name",scope='asia',template='seaborn',title='Impack of lockdown on Employement across regions')

fig.layout.updatemenus[0].buttons[0].args[1]["frame"]["duration"] = 3000

fig.update_geos(lataxis_range=[5,35], lonaxis_range=[65, 100],oceancolor="#3399FF",
    showocean=True)

fig.show()
# Out:
# <div>                            <div id="57e90e42-95f3-468b-b1ca-b15d8fc95eac" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("57e90e42-95f3-468b-b1ca-b15d8fc95eac")) {                    Plotly.newPlot(                        "57e90e42-95f3-468b-b1ca-b15d8fc95eac",                        [{"geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>Region=Andhra Pradesh<br>Month_name=May<br>Estimates Unemployment Rate (%)=%{marker.size}<br>Area=%{lat}<extra></extra>","hovertext":["Andhra Pradesh","Andhra Pradesh","Andhra Pradesh","Andhra Pradesh"],"lat":["Rural","Rural","Urban","Urban"],"legendgroup":"Andhra Pradesh","marker":{"color":"rgb(76,114,176)","size":[3.65,14.46,6.09,24.91],"sizemode":"area","sizeref":0.19185,"symbol":"circle"},"mode":"marker
# ...

# %%
#data representation before and after the lockdown
after_lockdown = df[(df['Month_int'] >= 4) & (df['Month_int'] <=6)]
before_lockdown = df[(df['Month_int'] >= 1) & (df['Month_int'] <=4)]

# %%
af_lockdown=after_lockdown.groupby('Region')['Estimates Unemployment Rate (%)'].mean().reset_index()
lockdown= before_lockdown.groupby('Region')['Estimates Unemployment Rate (%)'].mean().reset_index()
lockdown['Unemployment Rate before lockdown'] = af_lockdown['Estimates Unemployment Rate (%)']

lockdown.columns=['Region','Unemployment Rate Before Lockdown','Unemployment Rate After Lockdown']
lockdown.head()
# Out:
#            Region  Unemployment Rate Before Lockdown  \
# 0  Andhra Pradesh                          10.756250
# 1           Assam                           6.750000
# 2           Bihar                          23.690000
# 3      Chandigarh                          19.366667
# 4    Chhattisgarh                           9.028750
#
#    Unemployment Rate After Lockdown
# 0                         11.126000
# 1                          6.563333
# 2                         27.459000
# 3                         12.656667
# 4                         12.720000

# %%
# percentage change in unemployment rate

lockdown['rate change in unemployment'] = round(lockdown['Unemployment Rate After Lockdown'] -lockdown['Unemployment Rate Before Lockdown']/lockdown['Unemployment Rate Before Lockdown'],2)
plot_per = lockdown.sort_values('rate change in unemployment')

# %%
# percentage change in unemployment after lockdown

fig = px.bar(plot_per, x='Region',y='rate change in unemployment',color='rate change in unemployment',
            title='percentage change in Unemployment in each state after lockdown',template='ggplot2')
fig.show()
# Out:
# <div>                            <div id="b16c8c37-6c6f-4ae1-bbb0-0e58e1bd992f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b16c8c37-6c6f-4ae1-bbb0-0e58e1bd992f")) {                    Plotly.newPlot(                        "b16c8c37-6c6f-4ae1-bbb0-0e58e1bd992f",                        [{"alignmentgroup":"True","hovertemplate":"Region=%{x}<br>rate change in unemployment=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[5.56,6.13,6.37,6.76,7.57,7.81,9.3,9.35,10.13,10.3,11.29,11.47,11.66,11.72,12.79,13.45,13.56,13.98,14.4,14.62,15.48,18.2,18.48,26.25,26.46,28.01,29.89,31.27],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Assam","Sikkim","
# ...

# %%
# function to sort value based on impact

def sort_impact(x):
    if x <= 10:
        return 'impacted States'
    elif x <= 20:
        return 'hard impacted States'
    elif x <= 30:
        return 'harder impacted States'
    elif x <= 46:
        return 'hardest impacted States'
    return x

# %%
plot_per['impact status'] = plot_per['rate change in unemployment'].apply(lambda x:sort_impact(x))

# %%
fig = px.bar(plot_per, y='Region',x='rate change in unemployment',color='impact status',
            title='Impact of lockdown on employment across states',template='ggplot2',height=650)


fig.show()
# Out:
# <div>                            <div id="476529fb-cb6a-4228-aa77-cc8685636b5a" class="plotly-graph-div" style="height:650px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("476529fb-cb6a-4228-aa77-cc8685636b5a")) {                    Plotly.newPlot(                        "476529fb-cb6a-4228-aa77-cc8685636b5a",                        [{"alignmentgroup":"True","hovertemplate":"impact status=impacted States<br>rate change in unemployment=%{x}<br>Region=%{y}<extra></extra>","legendgroup":"impacted States","marker":{"color":"#F8766D","pattern":{"shape":""}},"name":"impacted States","offsetgroup":"impacted States","orientation":"h","showlegend":true,"textposition":"auto","x":[5.56,6.13,6.37,6.76,7.57,7.81,9.3,9.35],"xaxis":"x","y":["Assam","Sikkim","Uttarakhand","Meghalaya","Odisha","Gujarat","Goa"
# ...
